# %% [markdown]
# # Data Mining Practical-4
#
# Name - **Harsh Bamotra** <br>
# Roll No. - **AC-1216** <br>
# Course - **BSc. (H) Computer Science**

# %% [markdown]
# **Importing required libraries**

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ### *Q. Run Apriori algorithm to find frequent itemsets and association rules :- <br><br>1. Use minimum support as 50% and minimum confidence as 75%.*

# %% [markdown]
# **Reading data from csv file**

# %%
df = pd.read_csv('basket_analysis.csv', index_col=0) 
df.head(5)
# Out:
#    Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  Kidney Beans  \
# 0  False   True   False   False   True   True  False       True         False
# 1  False  False   False   False  False  False  False      False         False
# 2   True  False    True   False  False   True  False       True         False
# 3  False  False    True    True  False   True  False      False         False
# 4   True   True   False   False  False  False  False      False         False
#
#     Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0  False   False  False   True    False    True       True
# 1   True   False  False  False    False   False      False
# 2   True   False  False  False    False    True       True
# 3   True    True   True  False    False   False      False
# 4  False   False  False  False    False   False      False

# %% [markdown]
# **Calculating frequent items using minimum support as 50%**

# %%
freq_items = apriori(df, min_support=0.05, use_colnames=True) 
freq_items
# Out:
#       support                            itemsets
# 0    0.383383                             (Apple)
# 1    0.384384                             (Bread)
# 2    0.420420                            (Butter)
# 3    0.404404                            (Cheese)
# 4    0.407407                              (Corn)
# ..        ...                                 ...
# 942  0.051051   (chocolate, Onion, Milk, Unicorn)
# 943  0.050050    (chocolate, Yogurt, Onion, Milk)
# 944  0.054054  (chocolate, Yogurt, Onion, Nutmeg)
# 945  0.051051     (Yogurt, Onion, Sugar, Unicorn)
# 946  0.052052  (chocolate, Onion, Sugar, Unicorn)
#
# [947 rows x 2 columns]

# %% [markdown]
# **Calculating association rule using minimum confidence as 75%**

# %%
association_rules(freq_items, metric="confidence", min_threshold=0.075)
# Out:
#            antecedents                  consequents  antecedent support  \
# 0              (Apple)                      (Bread)            0.383383
# 1              (Bread)                      (Apple)            0.384384
# 2              (Apple)                     (Butter)            0.383383
# 3             (Butter)                      (Apple)            0.420420
# 4              (Apple)                     (Cheese)            0.383383
# ...                ...                          ...                 ...
# 7109  (Sugar, Unicorn)           (chocolate, Onion)            0.181181
# 7110       (chocolate)      (Onion, Sugar, Unicorn)            0.421421
# 7111           (Onion)  (chocolate, Sugar, Unicorn)            0.403403
# 7112           (Sugar)  (chocolate, Onion, Unicorn)            0.409409
# 7113         (Unicorn)    (chocolate, Onion, Sugar)            0.389389
#
#       consequent support   support  confidence      lift  leverage  \
# 0               0.384384  0.154154    0.402089  1.046059  0.006788
# 1               0.383383  0.154154    0.401042  1.046059  0.006788
# 2               0.420420  0.188188    0.490862  1.167549  0.027006
# 3               0.383383  0.188188    0.447619  1.167549  0.027006
# 4               0.404404  0.162162    0.422977  1.045925  0.007120
# ...                  ...       ...         ...       ...       ...
# 7109            0.196196  0.052052    0.287293  1.464314  0.016505
# 7110            0.096096  0.052052    0.123515  1.285333  0.011555
# 7111            0.090090  0.052052    0.129032  1.432258  0.015709
# 7112            0.099099  0.052052    0.127139  1.282952  0.011480
# 7113            0.091091  0.052052    0.133676  1.467499  0.016582
#
#       conviction  zhangs_metric
# 0       1.029610       0.071407
# 1       1.029482       0.071524
# 2       1.138354       0.232730
# 3       1.116289       0.247602
# 4       1.032186       0.071208
# ...          ...            ...
# 7109    1.127818       0.387248
# 7110    1.031283       0.383684
# 7111    1.044711       0.505872
# 7112    1.032125       0.373435
# 7113    1.049156       0.521721
#
# [7114 rows x 10 columns]

# %% [markdown]
# ### *2. Use minimum support as 60% and minimum confidence as 60 %.*

# %% [markdown]
# **Reading data from csv file**

# %%
df2 = pd.read_csv('basket_analysis.csv', index_col=0)
df2.head(5)
# Out:
#    Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  Kidney Beans  \
# 0  False   True   False   False   True   True  False       True         False
# 1  False  False   False   False  False  False  False      False         False
# 2   True  False    True   False  False   True  False       True         False
# 3  False  False    True    True  False   True  False      False         False
# 4   True   True   False   False  False  False  False      False         False
#
#     Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0  False   False  False   True    False    True       True
# 1   True   False  False  False    False   False      False
# 2   True   False  False  False    False    True       True
# 3   True    True   True  False    False   False      False
# 4  False   False  False  False    False   False      False

# %% [markdown]
# **Calculating frequent items using minimum support as 60%**

# %%
freq_items2 = apriori(df2, min_support=0.06,use_colnames=True) 
freq_items2
# Out:
#       support                           itemsets
# 0    0.383383                            (Apple)
# 1    0.384384                            (Bread)
# 2    0.420420                           (Butter)
# 3    0.404404                           (Cheese)
# 4    0.407407                             (Corn)
# ..        ...                                ...
# 693  0.090090        (chocolate, Sugar, Unicorn)
# 694  0.095095         (chocolate, Yogurt, Sugar)
# 695  0.086086       (chocolate, Yogurt, Unicorn)
# 696  0.062062   (chocolate, Dill, Milk, Unicorn)
# 697  0.060060  (chocolate, Dill, Onion, Unicorn)
#
# [698 rows x 2 columns]

# %% [markdown]
# **Calculating association rule using minimum confidence as 60%**

# %%
association_rules(freq_items2, metric="confidence", min_threshold=0.06)
# Out:
#            antecedents                  consequents  antecedent support  \
# 0              (Apple)                      (Bread)            0.383383
# 1              (Bread)                      (Apple)            0.384384
# 2              (Apple)                     (Butter)            0.383383
# 3             (Butter)                      (Apple)            0.420420
# 4              (Apple)                     (Cheese)            0.383383
# ...                ...                          ...                 ...
# 3623  (Onion, Unicorn)            (chocolate, Dill)            0.175175
# 3624       (chocolate)       (Dill, Onion, Unicorn)            0.421421
# 3625            (Dill)  (chocolate, Onion, Unicorn)            0.398398
# 3626           (Onion)   (chocolate, Dill, Unicorn)            0.403403
# 3627         (Unicorn)     (chocolate, Dill, Onion)            0.389389
#
#       consequent support   support  confidence      lift  leverage  \
# 0               0.384384  0.154154    0.402089  1.046059  0.006788
# 1               0.383383  0.154154    0.401042  1.046059  0.006788
# 2               0.420420  0.188188    0.490862  1.167549  0.027006
# 3               0.383383  0.188188    0.447619  1.167549  0.027006
# 4               0.404404  0.162162    0.422977  1.045925  0.007120
# ...                  ...       ...         ...       ...       ...
# 3623            0.199199  0.060060    0.342857  1.721177  0.025165
# 3624            0.093093  0.060060    0.142518  1.530917  0.020829
# 3625            0.099099  0.060060    0.150754  1.521243  0.020579
# 3626            0.101101  0.060060    0.148883  1.472619  0.019276
# 3627            0.103103  0.060060    0.154242  1.495994  0.019913
#
#       conviction  zhangs_metric
# 0       1.029610       0.071407
# 1       1.029482       0.071524
# 2       1.138354       0.232730
# 3       1.116289       0.247602
# 4       1.032186       0.071208
# ...          ...            ...
# 3623    1.218610       0.507989
# 3624    1.057639       0.599394
# 3625    1.060824       0.569551
# 3626    1.056141       0.537947
# 3627    1.060465       0.542978
#
# [3628 rows x 10 columns]
